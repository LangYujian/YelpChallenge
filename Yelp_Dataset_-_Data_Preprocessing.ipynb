# %% [markdown]
# # Yelp Data Challenge - Data Preprocessing
#
# BitTiger DS501
#
# Jun 2017

# %% [markdown]
# ## Dataset Introduction
#
# [Yelp Dataset Challenge](https://www.yelp.com/dataset_challenge)
#
# The Challenge Dataset:
#
#     4.1M reviews and 947K tips by 1M users for 144K businesses
#     1.1M business attributes, e.g., hours, parking availability, ambience.
#     Aggregated check-ins over time for each of the 125K businesses
#     200,000 pictures from the included businesses
#
# Cities:
#
#     U.K.: Edinburgh
#     Germany: Karlsruhe
#     Canada: Montreal and Waterloo
#     U.S.: Pittsburgh, Charlotte, Urbana-Champaign, Phoenix, Las Vegas, Madison, Cleveland
#
# Files:
#
#     yelp_academic_dataset_business.json
#     yelp_academic_dataset_checkin.json
#     yelp_academic_dataset_review.json
#     yelp_academic_dataset_tip.json
#     yelp_academic_dataset_user.json
#
# Notes on the Dataset
#
#     Each file is composed of a single object type, one json-object per-line.
#     Take a look at some examples to get you started: https://github.com/Yelp/dataset-examples.

# %% [markdown]
# ## Read data from file and load to Pandas DataFrame
#
# **Warning**: Loading all the 1.8 GB data into Pandas at a time takes long time and a lot of memory!

# %%
import json
import pandas as pd
import numpy as np

# %%
file_business, file_checkin, file_review, file_tip, file_user = [
    'yelp_dataset_challenge_round9/yelp_academic_dataset_business.json',
    'yelp_dataset_challenge_round9/yelp_academic_dataset_checkin.json',
    'yelp_dataset_challenge_round9/yelp_academic_dataset_review.json',
    'yelp_dataset_challenge_round9/yelp_academic_dataset_tip.json',
    'yelp_dataset_challenge_round9/yelp_academic_dataset_user.json'
]

# %% [markdown]
# #### Business Data

# %%
with open(file_business) as f:
    df_business = pd.DataFrame(json.loads(line) for line in f)

# %%
df_business.head()
# Out:
#                      address  \
# 0  227 E Baseline Rd, Ste J2
# 1   495 S Grand Central Pkwy
# 2         979 Bloor Street W
# 3     7014 Steubenville Pike
# 4          321 Jarvis Street
#
#                                           attributes             business_id  \
# 0  [BikeParking: True, BusinessAcceptsBitcoin: Fa...  0DI8Dt2PJp07XkVvIElIcQ
# 1  [BusinessAcceptsBitcoin: False, BusinessAccept...  LTlCaCGZE14GuaUXUGbamg
# 2  [Alcohol: none, Ambience: {'romantic': False, ...  EDqCEAGXVGCH4FJXgqtjqg
# 3  [AcceptsInsurance: False, BusinessAcceptsCredi...  cnGIivYRLxpF7tBVR_JwWA
# 4  [BusinessAcceptsCreditCards: True, Restaurants...  cdk-qqJ71q6P7TJTww_DSA
#
#                                           categories       city  \
# 0   [Tobacco Shops, Nightlife, Vape Shops, Shopping]      Tempe
# 1  [Caterers, Grocery, Food, Event Planning & Ser...  Las Vegas
# 2       [Restaurants, Pizza, Chicken Wings, Italian]    Toronto
# 3  [Hair Removal, Beauty & Spas, Blow Dry/Out Ser...    Oakdale
# 4  [Hotels & Travel, Event Planning & Services, H...    Toronto
#
#                                                hours  is_open   latitude  \
# 0  [Monday 11:0-21:0, Tuesday 11:0-21:0, Wednesda...        0  33.378214
# 1  [Monday 0:0-0:0, Tuesday 0:0-0:0, Wednesday 0:...        1  36.192284
# 2  [Monday 11:0-2:0, Tuesday 11:0-2:0, Wednesday ...        1  43.661054
# 3  [Tuesday 10:0-21:0, Wednesday 10:0-21:0, Thurs...        1  40.444544
# 4                                               None        1  43.659829
#
#     longitude                 name    neighborhood postal_code  review_count  \
# 0 -111.936102    Innovative Vapors                       85283            17
# 1 -115.159272        Cut and Taste                       89106             9
# 2  -79.429089          Pizza Pizza  Dufferin Grove     M6H 1L5             7
# 3  -80.174540  Plush Salon and Spa                       15071             4
# 4  -79.375401          Comfort Inn   Downtown Core     M5B 2C2             8
#
#    stars state      type
# 0    4.5    AZ  business
# 1    5.0    NV  business
# 2    2.5    ON  business
# 3    4.0    PA  business
# 4    3.0    ON  business

# %%
df_business.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 144072 entries, 0 to 144071
# Data columns (total 16 columns):
# address         144072 non-null object
# attributes      127162 non-null object
# business_id     144072 non-null object
# categories      143747 non-null object
# city            144072 non-null object
# hours           102464 non-null object
# is_open         144072 non-null int64
# latitude        144072 non-null float64
# longitude       144072 non-null float64
# name            144072 non-null object
# neighborhood    144072 non-null object
# postal_code     144072 non-null object
# review_count    144072 non-null int64
# stars           144072 non-null float64
# state           144072 non-null object
# type            144072 non-null object
# dtypes: float64(3), int64(2), object(11)
# memory usage: 17.6+ MB

# %% [markdown]
# #### Checkin Data

# %%
# with open(file_checkin) as f:
#     df_checkin = pd.DataFrame(json.loads(line) for line in f)
# df_checkin.head(2)

# %% [markdown]
# #### Review Data

# %%
# with open(file_review) as f:
#     df_review = pd.DataFrame(json.loads(line) for line in f)
# df_review.head(2)

# %% [markdown]
# #### Tip Data

# %%
# with open(file_tip) as f:
#     df_tip = pd.DataFrame(json.loads(line) for line in f)
# df_tip.head(2)

# %% [markdown]
# #### User Data

# %%
# with open(file_user) as f:
#     df_user = pd.DataFrame(json.loads(line) for line in f)
# df_user.head(2)

# %% [markdown]
# ## Filter data by city and category

# %% [markdown]
# #### Create filters/masks
#
# * create filters that selects business
#     * that are located in "Las Vegas"
#     * that contains "Restaurants" in their category (You may need to filter null categories first)

# %%
# Create Pandas DataFrame filters
names = df_business.columns
shape = df_business.shape
print(names)
# Out:
# Index([u'address', u'attributes', u'business_id', u'categories', u'city',
#        u'hours', u'is_open', u'latitude', u'longitude', u'name',
#        u'neighborhood', u'postal_code', u'review_count', u'stars', u'state',
#        u'type'],
#       dtype='object')

# %%
# Fill 'None' as Categories for the columns with no category
Correct_City = (df_business['city'] == 'Las Vegas')
Correct_Category = ~ pd.isnull(df_business['categories'])
for i in xrange(shape[0]):
    if Correct_Category[i]:
        Correct_Category[i] = 'Restaurants' in df_business['categories'][i]

# %%
filters = Correct_City & Correct_Category

# %%
# Create filtered DataFrame, and name it df_filtered
df_filtered = df_business[filters]

# %%
CorrectCity = df_business['city'] == 'Las Vegas'
CorrectCategory = df_business['categories'].apply(lambda x: x is not None and 'Restaurants' in x)
Filter = CorrectCity&CorrectCategory
df_business[Filter]
# Out:
#                                                   address  \
# 37                                    4811 S Rainbow Blvd
# 71                           4972 S Maryland Pkwy, Ste 22
# 72                                           2053 Pama Ln
# 102                                      4341 N Rancho Dr
# 103                                      4949 N Rancho Dr
# 154                                     2230 W Bonanza Rd
# 177                                7002 W Charleston Blvd
# 179                           7501 N Cimarron Rd, Ste 108
# 184                                  7930 W Tropical Pkwy
# 260                            1930 N Decatur Blvd, Ste 1
# 269                                  4747 S Maryland Pkwy
# 299                         2620 S Maryland Pkwy, Ste 176
# 300                                      3000 Paradise Rd
# 325                               8635 Spring Mountain Rd
# 418                      3717 S Las Vegas Blvd, Ste 140-A
# 430                                 3900 Las Vegas Blvd S
# 434                             10220 W Charleston, Ste 2
# 443                                 3355 Las Vegas Blvd S
# 444       Riviera Hotel and Casino, 2901 Las Vegas Blvd S
# 478                             4875 West Oakey Boulevard
# 479                                     4400 W Sahara Ave
# 629                             8520 W. Warm Springs Road
# 658                                 6055 E Lake Mead Blvd
# 701                                    238 S Rainbow Blvd
# 713                                   1920 N Decatur Blvd
# 723                          4632 S Maryland Pkwy, Ste 12
# 754                                     7865 W Sahara Ave
# 778                                  8650 W Tropicana Ave
# 779                                     4105 W Sahara Ave
# 807                          7320 S Rainbow Blvd, Ste 105
# ...                                                   ...
# 143232                    8170 S Eastern Avenue, Suite 12
# 143233                        9620 Las Vegas Blvd, Ste E5
# 143255                                 4321 W Flamingo Rd
# 143302                       6584 N Decatur Blvd, Ste 100
# 143314                              9111 Las Vegas Blvd S
# 143354                                8300 W Cheyenne Ave
# 143357                          3400 S Jones Blvd, Ste 15
# 143359                     5455 S Fort Apache Rd, Ste 105
# 143429                      1725 E Warm Springs Rd, Ste 9
# 143581                               6125 W Tropicana Ave
# 143615                                 4815 W Flamingo Rd
# 143636                                 9055 S Eastern Ave
# 143641                          4180 S Jones Blvd, Unit 1
# 143663                                   4416 N Rancho Dr
# 143666                                 9510 S Eastern Ave
# 143683  Stratosphere Hotel & Casino, 2000 Las Vegas Bl...
# 143714                              8540 S. Maryland Pkwy
# 143715                                  2310 E Serene Ave
# 143717                                 9460 S Eastern Ave
# 143720                                 6820 W Flamingo Rd
# 143721                     Gold Coast, 4000 W Flamingo Rd
# 143784        Delano Las Vegas, 3940 Las Vegas Blvd South
# 143803                            4804 W Lone Mountain Rd
# 143805                           505 E Windmill Ln, Ste D
# 143807                                  415 E Windmill Ln
# 143817                          4983 W Flamingo Rd, Ste B
# 143889                    Serene Plaza, 1860 E Serene Ave
# 143998                                 3137 Industrial Rd
# 144018                         7785 N Durango Dr, Ste 135
# 144054                            450 Fremont St, Ste 110
#
#                                                attributes  \
# 37      [Alcohol: full_bar, BusinessAcceptsCreditCards...
# 71      [Alcohol: none, Ambience: {'romantic': False, ...
# 72      [Ambience: {'romantic': False, 'intimate': Fal...
# 102     [Alcohol: full_bar, Ambience: {'romantic': Fal...
# 103     [Alcohol: none, Ambience: {'romantic': False, ...
# 154     [Alcohol: none, BusinessAcceptsCreditCards: Tr...
# 177     [Alcohol: beer_and_wine, BusinessAcceptsCredit...
# 179     [Alcohol: none, Ambience: {'romantic': False, ...
# 184     [Alcohol: beer_and_wine, Ambience: {'romantic'...
# 260     [Alcohol: beer_and_wine, Ambience: {'romantic'...
# 269     [Alcohol: none, Ambience: {'romantic': False, ...
# 299     [Alcohol: none, Ambience: {'romantic': False, ...
# 300     [Alcohol: full_bar, Ambience: {'romantic': Fal...
# 325     [Alcohol: none, Ambience: {'romantic': False, ...
# 418     [Alcohol: full_bar, BikeParking: False, Busine...
# 430     [Alcohol: full_bar, Ambience: {'romantic': Fal...
# 434     [Alcohol: none, Ambience: {'romantic': False, ...
# 443     [Ambience: {'romantic': False, 'intimate': Fal...
# 444     [BusinessAcceptsCreditCards: True, Restaurants...
# 478     [BusinessAcceptsCreditCards: True, Restaurants...
# 479     [Alcohol: none, Ambience: {'romantic': False, ...
# 629     [Alcohol: none, Ambience: {'romantic': False, ...
# 658     [Alcohol: beer_and_wine, Ambience: {'romantic'...
# 701     [BikeParking: True, BusinessAcceptsCreditCards...
# 713     [Alcohol: none, Ambience: {'romantic': False, ...
# 723     [Alcohol: none, Ambience: {'romantic': False, ...
# 754     [Alcohol: beer_and_wine, Ambience: {'romantic'...
# 778     [Alcohol: none, Ambience: {'romantic': False, ...
# 779     [BikeParking: False, BusinessAcceptsCreditCard...
# 807     [Alcohol: none, Ambience: {'romantic': False, ...
# ...                                                   ...
# 143232  [BusinessAcceptsCreditCards: True, GoodForKids...
# 143233  [Alcohol: none, Ambience: {'romantic': False, ...
# 143255  [BikeParking: False, BusinessAcceptsCreditCard...
# 143302  [Alcohol: none, Ambience: {'romantic': False, ...
# 143314  [Alcohol: none, Ambience: {'romantic': False, ...
# 143354  [Alcohol: none, Ambience: {'romantic': False, ...
# 143357  [Alcohol: full_bar, Ambience: {'romantic': Fal...
# 143359  [Alcohol: beer_and_wine, Ambience: {'romantic'...
# 143429  [Alcohol: none, Ambience: {'romantic': False, ...
# 143581  [Alcohol: full_bar, Ambience: {'romantic': Fal...
# 143615  [Alcohol: none, BikeParking: True, BusinessAcc...
# 143636  [BusinessAcceptsCreditCards: True, BusinessPar...
# 143641  [Alcohol: full_bar, Ambience: {'romantic': Fal...
# 143663  [Alcohol: none, Ambience: {'romantic': False, ...
# 143666  [Alcohol: full_bar, Ambience: {'romantic': Fal...
# 143683  [BusinessAcceptsCreditCards: True, WheelchairA...
# 143714  [Alcohol: full_bar, BusinessAcceptsCreditCards...
# 143715  [BikeParking: True, BusinessAcceptsCreditCards...
# 143717  [BYOB: False, BusinessAcceptsCreditCards: True...
# 143720  [Alcohol: beer_and_wine, Ambience: {'romantic'...
# 143721  [Alcohol: beer_and_wine, Ambience: {'romantic'...
# 143784  [Alcohol: full_bar, Ambience: {'romantic': Fal...
# 143803  [Alcohol: none, Ambience: {'romantic': False, ...
# 143805  [Alcohol: none, Ambience: {'romantic': False, ...
# 143807  [Alcohol: full_bar, Ambience: {'romantic': Fal...
# 143817  [Alcohol: none, BikeParking: False, BusinessAc...
# 143889  [BikeParking: False, BusinessAcceptsCreditCard...
# 143998  [Alcohol: none, Ambience: {'romantic': False, ...
# 144018  [Alcohol: none, Ambience: {'romantic': False, ...
# 144054  [Alcohol: beer_and_wine, Ambience: {'romantic'...
#
#                    business_id  \
# 37      saWZO6hB4B8P-mIzS1--Xw
# 71      hMh9XOwNQcu31NAOCqhAEw
# 72      pmJqSsCfgbo3TxPWpQNLIw
# 102     kUUBBLBHCasOl2a5nW9nAw
# 103     A2pZTpFXWC38z506XIhnBQ
# 154     InDH4ZQ_byiQ5PyaqgHI8Q
# 177     WleVOQ9YhBYl4SWrlsLDhA
# 179     gMUAn6xcuE-TbY1seFw_Ww
# 184     kUntNQ5P9IrRzEoHdRxV-w
# 260     -vb_yx5QnIhpXUIdPVD2og
# 269     3rkxTx8DoZSl7_FryhXCVQ
# 299     kJl3l4fSa2spv_Mkhgogmg
# 300     CCNp1qS8n2gh51X7Wadabw
# 325     rECgTdKelvefty5JIXHDbg
# 418     mB_cI1tCrNxxvr2e2myNrQ
# 430     KaGZE0_o1EmmSN4Fo_cpUw
# 434     RxZpGcmMmUUlLn8c6RTk8w
# 443     8cn8zqkyz-UpGKXcKeIRYA
# 444     F7E3qP0oz_SuVGZGL0D8Zw
# 478     QVcSKzl47nrO_LWFzz5AJQ
# 479     1tNVPumjvFErYjvSXbOQ6Q
# 629     cJ5i4V6_VKjkOeEHD4ENeQ
# 143714 -115.135957                 Timbers Bar & Grill      Southeast
# 143715 -115.124110                          McDonald's      Southeast
# 143717 -115.118284           Sweet Water Prime Seafood      Southeast
# 143720 -115.241355    Tasty Island Jamaican Restaurant
# 143721 -115.192881                     Noodle Exchange
# 143784 -115.177524                     Della's Kitchen      The Strip
# 143803 -115.208005                          McDonald's      Northwest
# 143805 -115.151932                       China a Go Go      Southeast
# 143807 -115.154050                       Express Pizza      Southeast
# 143817 -115.209744                Shang Artisan Noodle
# 143889 -115.126616   Filipino Fast Food & Asian Market      Southeast
# 143998 -115.172826                        Thai St Cafe
# 144018 -115.282062                     Seafood Station     Centennial
# 144054 -115.140684                       LV Food Junky       Downtown
#
#        postal_code  review_count  stars state      type
# 37           89103            15    2.5    NV  business
# 71           89119            33    3.5    NV  business
# 72           89119            35    4.5    NV  business
# 102          89130             9    3.5    NV  business
# 103          89130            41    3.5    NV  business
# 154          89106             6    2.0    NV  business
# 177          89145             6    3.5    NV  business
# 179          89131           132    4.5    NV  business
# 184          89149            74    3.5    NV  business
# 260          89108             7    3.5    NV  business
# 269          89119            34    3.5    NV  business
# 299          89109           103    3.5    NV  business
# 300          89109            60    2.0    NV  business
# 325          89117            36    2.0    NV  business
# 418          89109            76    3.0    NV  business
# 430          89119           198    3.0    NV  business
# 434          89135            13    3.5    NV  business
# 443          89109             6    2.0    NV  business
# 444          89109             3    3.0    NV  business
# 478          89102             4    5.0    NV  business
# 479          89102             8    2.0    NV  business
# 629          89113            27    3.0    NV  business
# 658          89156           120    4.5    NV  business
# 701          89145            12    2.5    NV  business
# 713          89108            40    5.0    NV  business
# 723          89119            22    4.5    NV  business
# 754          89117            82    4.5    NV  business
# 778          89147            48    3.5    NV  business
# 779          89102            21    4.5    NV  business
# 807          89139            15    3.0    NV  business
# ...            ...           ...    ...   ...       ...
# 143232       89123             3    3.5    NV  business
# 143233       89123           155    4.0    NV  business
# 143255       89103            12    1.5    NV  business
# 143302       89131            94    3.5    NV  business
# 143314       89123            35    3.5    NV  business
# 143354       89129            45    2.5    NV  business
# 143357       89146           153    3.5    NV  business
# 143359       89148           207    4.0    NV  business
# 143429       89119           113    4.0    NV  business
# 143581       89103             5    2.0    NV  business
# 143615       89103            11    2.0    NV  business
# 143636       89123             4    5.0    NV  business
# 143641       89103            25    4.0    NV  business
# 143663       89130            36    3.0    NV  business
# 143666       89123            14    3.5    NV  business
# 143683       89104            15    3.5    NV  business
# 143714       89123             6    3.5    NV  business
# 143715       89123             9    1.5    NV  business
# 143717       89123             4    2.0    NV  business
# 143720       89103           102    3.0    NV  business
# 143721       89103           152    3.5    NV  business
# 143784       89119           259    3.5    NV  business
# 143803       89130            15    2.0    NV  business
# 143805       89123           111    3.5    NV  business
# 143807       89123            40    3.0    NV  business
# 143817       89103           169    4.5    NV  business
# 143889       89123             6    3.5    NV  business
# 143998       89109           504    4.0    NV  business
# 144018       89131            23    4.0    NV  business
# 144054       98011            50    5.0    NV  business
#
# [5431 rows x 16 columns]

# %% [markdown]
# #### Keep relevant columns
#
# * only keep some useful columns
#     * business_id
#     * name
#     * categories
#     * stars

# %%
selected_features = [u'business_id', u'name', u'categories', u'stars']

# %%
# Make a DataFrame that contains only the abovementioned columns, and name it as df_selected_business
df_selected_business = df_filtered[selected_features]
df_selected_business.head()
# Out:
#                 business_id                          name  \
# 37   saWZO6hB4B8P-mIzS1--Xw                  Kabob Palace
# 71   hMh9XOwNQcu31NAOCqhAEw                Taste of India
# 72   pmJqSsCfgbo3TxPWpQNLIw          Artisanal Foods Cafe
# 102  kUUBBLBHCasOl2a5nW9nAw  Bailey's Sports Bar & Eatery
# 103  A2pZTpFXWC38z506XIhnBQ                      Wingstop
#
#                                             categories  stars
# 37   [Persian/Iranian, Restaurants, Ethnic Food, Fo...    2.5
# 71                   [Restaurants, Vegetarian, Indian]    3.5
# 72                [American (New), Cafes, Restaurants]    4.5
# 102  [Nightlife, Bars, Restaurants, Thai, Sports Bars]    3.5
# 103            [Chicken Wings, Fast Food, Restaurants]    3.5

# %%
# Rename the column name "stars" to "avg_stars" to avoid naming conflicts with review dataset
df_selected_business['avg_stars'] = df_selected_business['stars']
df_selected_business = df_selected_business.drop('stars', axis = 1)
# Out:
# /usr/local/lib/python2.7/site-packages/ipykernel_launcher.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy

# %%
# Inspect your DataFrame
df_selected_business
df_selected_business.iloc[35]
# Out:
# business_id                               Uux8P1ruzjPTQgOeYx68rg
# name                                                   Nook Café
# categories     [Cafes, Coffee & Tea, Food, Breakfast & Brunch...
# avg_stars                                                    3.5
# Name: 903, dtype: object

# %% [markdown]
# #### Save results to csv files

# %%
# Save to ./data/selected_business.csv for your next task
df_selected_business.to_csv('./data/selected_business.csv', encoding = 'utf-8', index = False)

# %%
# Try reload the csv file to check if everything works fine
df_selected_business = pd.read_csv('./data/selected_business.csv')
df_selected_business.head()
# Out:
#               business_id                          name  \
# 0  saWZO6hB4B8P-mIzS1--Xw                  Kabob Palace
# 1  hMh9XOwNQcu31NAOCqhAEw                Taste of India
# 2  pmJqSsCfgbo3TxPWpQNLIw          Artisanal Foods Cafe
# 3  kUUBBLBHCasOl2a5nW9nAw  Bailey's Sports Bar & Eatery
# 4  A2pZTpFXWC38z506XIhnBQ                      Wingstop
#
#                                           categories  avg_stars
# 0  [Persian/Iranian, Restaurants, Ethnic Food, Fo...        2.5
# 1                  [Restaurants, Vegetarian, Indian]        3.5
# 2               [American (New), Cafes, Restaurants]        4.5
# 3  [Nightlife, Bars, Restaurants, Thai, Sports Bars]        3.5
# 4            [Chicken Wings, Fast Food, Restaurants]        3.5

# %% [markdown]
# ### Use the "business_id" column to filter review data
#
# * We want to make a DataFrame that contain and only contain the reviews about the business entities we just obtained

# %% [markdown]
# #### Load review dataset

# %%
with open(file_review) as f:
    df_review = pd.DataFrame(json.loads(line) for line in f)
df_review.head(2)
# Out:
#               business_id  cool        date  funny               review_id  \
# 0  2aFiy99vNLklCx3T_tGS9A     0  2011-10-10      0  NxL8SIC5yqOdnlXCg18IBg
# 1  2aFiy99vNLklCx3T_tGS9A     0  2010-12-29      0  pXbbIgOXvLuTi_SPs1hQEQ
#
#    stars                                               text    type  useful  \
# 0      5  If you enjoy service by someone who is as comp...  review       0
# 1      5  After being on the phone with Verizon Wireless...  review       1
#
#                   user_id
# 0  KpkOkG6RIf4Ra25Lhhxf1A
# 1  bQ7fQq1otn9hKX-gXRsrgA

# %% [markdown]
# #### Prepare dataframes to be joined, - on business_id

# %%
# Prepare the business dataframe and set index to column "business_id", and name it as df_left
df_left = df_selected_business.set_index('business_id')

# %%
# Prepare the review dataframe and set index to column "business_id", and name it as df_right
df_right = df_review.set_index('business_id')

# %%
# check df_left and df_right
df_left.head()
# Out:
#                                                 name  \
# business_id
# saWZO6hB4B8P-mIzS1--Xw                  Kabob Palace
# hMh9XOwNQcu31NAOCqhAEw                Taste of India
# pmJqSsCfgbo3TxPWpQNLIw          Artisanal Foods Cafe
# kUUBBLBHCasOl2a5nW9nAw  Bailey's Sports Bar & Eatery
# A2pZTpFXWC38z506XIhnBQ                      Wingstop
#
#                                                                categories  \
# business_id
# saWZO6hB4B8P-mIzS1--Xw  [Persian/Iranian, Restaurants, Ethnic Food, Fo...
# hMh9XOwNQcu31NAOCqhAEw                  [Restaurants, Vegetarian, Indian]
# pmJqSsCfgbo3TxPWpQNLIw               [American (New), Cafes, Restaurants]
# kUUBBLBHCasOl2a5nW9nAw  [Nightlife, Bars, Restaurants, Thai, Sports Bars]
# A2pZTpFXWC38z506XIhnBQ            [Chicken Wings, Fast Food, Restaurants]
#
#                         avg_stars
# business_id
# saWZO6hB4B8P-mIzS1--Xw        2.5
# hMh9XOwNQcu31NAOCqhAEw        3.5
# pmJqSsCfgbo3TxPWpQNLIw        4.5
# kUUBBLBHCasOl2a5nW9nAw        3.5
# A2pZTpFXWC38z506XIhnBQ        3.5

# %%
df_right.head()
# Out:
#                         cool        date  funny               review_id  \
# business_id
# 2aFiy99vNLklCx3T_tGS9A     0  2011-10-10      0  NxL8SIC5yqOdnlXCg18IBg
# 2aFiy99vNLklCx3T_tGS9A     0  2010-12-29      0  pXbbIgOXvLuTi_SPs1hQEQ
# 2aFiy99vNLklCx3T_tGS9A     0  2011-04-29      0  wslW2Lu4NYylb1jEapAGsw
# 2LfIuF3_sX6uwe-IR-P0jQ     1  2014-07-14      0  GP6YEearUWrzPtQYSF1vVg
# 2LfIuF3_sX6uwe-IR-P0jQ     0  2014-01-15      0  25RlYGq2s5qShi-pn3ufVA
#
#                         stars  \
# business_id
# 2aFiy99vNLklCx3T_tGS9A      5
# 2aFiy99vNLklCx3T_tGS9A      5
# 2aFiy99vNLklCx3T_tGS9A      5
# 2LfIuF3_sX6uwe-IR-P0jQ      5
# 2LfIuF3_sX6uwe-IR-P0jQ      4
#
#                                                                      text  \
# business_id
# 2aFiy99vNLklCx3T_tGS9A  If you enjoy service by someone who is as comp...
# 2aFiy99vNLklCx3T_tGS9A  After being on the phone with Verizon Wireless...
# 2aFiy99vNLklCx3T_tGS9A  Great service! Corey is very service oriented....
# 2LfIuF3_sX6uwe-IR-P0jQ  Highly recommended. Went in yesterday looking ...
# 2LfIuF3_sX6uwe-IR-P0jQ  I walked in here looking for a specific piece ...
#
#                           type  useful                 user_id
# business_id
# 2aFiy99vNLklCx3T_tGS9A  review       0  KpkOkG6RIf4Ra25Lhhxf1A
# 2aFiy99vNLklCx3T_tGS9A  review       1  bQ7fQq1otn9hKX-gXRsrgA
# 2aFiy99vNLklCx3T_tGS9A  review       0  r1NUhdNmL6yU9Bn-Yx6FTw
# 2LfIuF3_sX6uwe-IR-P0jQ  review       0  aW3ix1KNZAvoM8q-WghA3Q
# 2LfIuF3_sX6uwe-IR-P0jQ  review       0  YOo-Cip8HqvKp_p9nEGphw

# %% [markdown]
# #### Join! and reset index

# %%
# Join df_left and df_right. What type of join?
# inner join
df_merge = pd.merge(df_left, df_right, left_index = True, right_index = True, how = 'inner')

# %%
# You may want to reset the index 
df_merge.reset_index()
df_merge.head()
# Out:
#                                         name  \
# business_id
# --9e1ONYQuAa-CB_Rrw7Tw  Delmonico Steakhouse
# --9e1ONYQuAa-CB_Rrw7Tw  Delmonico Steakhouse
# --9e1ONYQuAa-CB_Rrw7Tw  Delmonico Steakhouse
# --9e1ONYQuAa-CB_Rrw7Tw  Delmonico Steakhouse
# --9e1ONYQuAa-CB_Rrw7Tw  Delmonico Steakhouse
#
#                                                       categories  avg_stars  \
# business_id
# --9e1ONYQuAa-CB_Rrw7Tw  [Steakhouses, Restaurants, Cajun/Creole]        4.0
# --9e1ONYQuAa-CB_Rrw7Tw  [Steakhouses, Restaurants, Cajun/Creole]        4.0
# --9e1ONYQuAa-CB_Rrw7Tw  [Steakhouses, Restaurants, Cajun/Creole]        4.0
# --9e1ONYQuAa-CB_Rrw7Tw  [Steakhouses, Restaurants, Cajun/Creole]        4.0
# --9e1ONYQuAa-CB_Rrw7Tw  [Steakhouses, Restaurants, Cajun/Creole]        4.0
#
#                         cool        date  funny               review_id  \
# business_id
# --9e1ONYQuAa-CB_Rrw7Tw     0  2015-06-26      0  nCqdz-NW64KazpxqnDr0sQ
# --9e1ONYQuAa-CB_Rrw7Tw     1  2010-03-25      1  pa4MASGD-2EFoR_rGDZILw
# --9e1ONYQuAa-CB_Rrw7Tw     1  2013-04-03      0  8N_ZSR4q3m2dTpWyB-ncCg
# --9e1ONYQuAa-CB_Rrw7Tw     0  2013-07-13      0  aVor8Ttm0RT3JBvv6DOWAQ
# --9e1ONYQuAa-CB_Rrw7Tw     0  2015-06-29      0  iwx6s6yQxc7yjS7NFANZig
#
#                         stars  \
# business_id
# --9e1ONYQuAa-CB_Rrw7Tw      1
# --9e1ONYQuAa-CB_Rrw7Tw      5
# --9e1ONYQuAa-CB_Rrw7Tw      1
# --9e1ONYQuAa-CB_Rrw7Tw      4
# --9e1ONYQuAa-CB_Rrw7Tw      4
#
#                                                                      text  \
# business_id
# --9e1ONYQuAa-CB_Rrw7Tw  I mainly went for the ceasar salad prepared ta...
# --9e1ONYQuAa-CB_Rrw7Tw  "WOW!!!" that's what she said... literally! lo...
# --9e1ONYQuAa-CB_Rrw7Tw  I visited this place with a few of my friends ...
# --9e1ONYQuAa-CB_Rrw7Tw  Delmonico is a terrific steakhouse, with great...
# --9e1ONYQuAa-CB_Rrw7Tw  Nice atmosphere and wonderful service. I had t...
#
#                           type  useful                 user_id
# business_id
# --9e1ONYQuAa-CB_Rrw7Tw  review       0  0XVzm4kVIAaH4eQAxWbhvw
# --9e1ONYQuAa-CB_Rrw7Tw  review       1  5aFBj0emFzoXsUcKbDQZiA
# --9e1ONYQuAa-CB_Rrw7Tw  review       1  n0y7p7B1NMia_3lpk7xK3A
# --9e1ONYQuAa-CB_Rrw7Tw  review       1  aP4BkNgP4wzQ5woQM-BI1A
# --9e1ONYQuAa-CB_Rrw7Tw  review       0  2aeNFntqY2QDZLADNo8iQQ

# %% [markdown]
# #### We further filter data by date, e.g. keep comments from last 2 years
#
# * Otherwise your laptop may crush on memory when running machine learning algorithms
# * Purposefully ignoring the reviews made too long time ago

# %%
# Make a filter that selects date after 2015-01-20
df_merge['date'] = pd.to_datetime(df_merge['date'])
df_merge.head()
# Out:
#                                         name  \
# business_id
# --9e1ONYQuAa-CB_Rrw7Tw  Delmonico Steakhouse
# --9e1ONYQuAa-CB_Rrw7Tw  Delmonico Steakhouse
# --9e1ONYQuAa-CB_Rrw7Tw  Delmonico Steakhouse
# --9e1ONYQuAa-CB_Rrw7Tw  Delmonico Steakhouse
# --9e1ONYQuAa-CB_Rrw7Tw  Delmonico Steakhouse
#
#                                                       categories  avg_stars  \
# business_id
# --9e1ONYQuAa-CB_Rrw7Tw  [Steakhouses, Restaurants, Cajun/Creole]        4.0
# --9e1ONYQuAa-CB_Rrw7Tw  [Steakhouses, Restaurants, Cajun/Creole]        4.0
# --9e1ONYQuAa-CB_Rrw7Tw  [Steakhouses, Restaurants, Cajun/Creole]        4.0
# --9e1ONYQuAa-CB_Rrw7Tw  [Steakhouses, Restaurants, Cajun/Creole]        4.0
# --9e1ONYQuAa-CB_Rrw7Tw  [Steakhouses, Restaurants, Cajun/Creole]        4.0
#
#                         cool       date  funny               review_id  stars  \
# business_id
# --9e1ONYQuAa-CB_Rrw7Tw     0 2015-06-26      0  nCqdz-NW64KazpxqnDr0sQ      1
# --9e1ONYQuAa-CB_Rrw7Tw     1 2010-03-25      1  pa4MASGD-2EFoR_rGDZILw      5
# --9e1ONYQuAa-CB_Rrw7Tw     1 2013-04-03      0  8N_ZSR4q3m2dTpWyB-ncCg      1
# --9e1ONYQuAa-CB_Rrw7Tw     0 2013-07-13      0  aVor8Ttm0RT3JBvv6DOWAQ      4
# --9e1ONYQuAa-CB_Rrw7Tw     0 2015-06-29      0  iwx6s6yQxc7yjS7NFANZig      4
#
#                                                                      text  \
# business_id
# --9e1ONYQuAa-CB_Rrw7Tw  I mainly went for the ceasar salad prepared ta...
# --9e1ONYQuAa-CB_Rrw7Tw  "WOW!!!" that's what she said... literally! lo...
# --9e1ONYQuAa-CB_Rrw7Tw  I visited this place with a few of my friends ...
# --9e1ONYQuAa-CB_Rrw7Tw  Delmonico is a terrific steakhouse, with great...
# --9e1ONYQuAa-CB_Rrw7Tw  Nice atmosphere and wonderful service. I had t...
#
#                           type  useful                 user_id
# business_id
# --9e1ONYQuAa-CB_Rrw7Tw  review       0  0XVzm4kVIAaH4eQAxWbhvw
# --9e1ONYQuAa-CB_Rrw7Tw  review       1  5aFBj0emFzoXsUcKbDQZiA
# --9e1ONYQuAa-CB_Rrw7Tw  review       1  n0y7p7B1NMia_3lpk7xK3A
# --9e1ONYQuAa-CB_Rrw7Tw  review       1  aP4BkNgP4wzQ5woQM-BI1A
# --9e1ONYQuAa-CB_Rrw7Tw  review       0  2aeNFntqY2QDZLADNo8iQQ

# %%
df_merge_filtered = df_merge.copy()
boundary = pd.to_datetime('2015-01-20')

# %%
# Filter the joined DataFrame and name it as df_final
df_final = df_merge_filtered[df_merge_filtered['date'] >= boundary].copy()

# %% [markdown]
# #### Take a glance at the final dataset
#
# * Do more EDA here as you like!

# %%
import matplotlib.pyplot as plt

% matplotlib inline

# %%
# e.g. calculate counts of reviews per business entity, and plot it
df_final['count'] = 1
df_review_num = df_final[['count']].groupby('business_id').sum()

# %%
# ouput the reviews per business entity
df_review_num.head()
# Out:
#                         count
# business_id
# --9e1ONYQuAa-CB_Rrw7Tw    318
# -1vfRrlnNnNJ5boOVghMPA     14
# -3zffZUHoY8bQjGfPSoBKQ    126
# -8R_-EkGpUhBk55K9Dd4mg     35
# -9YyInW1wapzdNZrhQJ9dg     50

# %%
df_reviews_text = df_merge_filtered[df_merge_filtered['date'] >= boundary].copy()
df_reviews_text.groupby('business_id')
df_reviews_text.head()
# Out:
#                                         name  \
# business_id
# --9e1ONYQuAa-CB_Rrw7Tw  Delmonico Steakhouse
# --9e1ONYQuAa-CB_Rrw7Tw  Delmonico Steakhouse
# --9e1ONYQuAa-CB_Rrw7Tw  Delmonico Steakhouse
# --9e1ONYQuAa-CB_Rrw7Tw  Delmonico Steakhouse
# --9e1ONYQuAa-CB_Rrw7Tw  Delmonico Steakhouse
#
#                                                       categories  avg_stars  \
# business_id
# --9e1ONYQuAa-CB_Rrw7Tw  [Steakhouses, Restaurants, Cajun/Creole]        4.0
# --9e1ONYQuAa-CB_Rrw7Tw  [Steakhouses, Restaurants, Cajun/Creole]        4.0
# --9e1ONYQuAa-CB_Rrw7Tw  [Steakhouses, Restaurants, Cajun/Creole]        4.0
# --9e1ONYQuAa-CB_Rrw7Tw  [Steakhouses, Restaurants, Cajun/Creole]        4.0
# --9e1ONYQuAa-CB_Rrw7Tw  [Steakhouses, Restaurants, Cajun/Creole]        4.0
#
#                         cool       date  funny               review_id  stars  \
# business_id
# --9e1ONYQuAa-CB_Rrw7Tw     0 2015-06-26      0  nCqdz-NW64KazpxqnDr0sQ      1
# --9e1ONYQuAa-CB_Rrw7Tw     0 2015-06-29      0  iwx6s6yQxc7yjS7NFANZig      4
# --9e1ONYQuAa-CB_Rrw7Tw     0 2015-04-05      0  2HrBENXZTiitcCJfzkELgA      2
# --9e1ONYQuAa-CB_Rrw7Tw     0 2016-02-16      0  6YNPXoq41qTMZ2TEi0BYUA      2
# --9e1ONYQuAa-CB_Rrw7Tw     0 2016-02-08      1  4bQrVUiRZ642odcKCS0OhQ      2
#
#                                                                      text  \
# business_id
# --9e1ONYQuAa-CB_Rrw7Tw  I mainly went for the ceasar salad prepared ta...
# --9e1ONYQuAa-CB_Rrw7Tw  Nice atmosphere and wonderful service. I had t...
# --9e1ONYQuAa-CB_Rrw7Tw  To be honest it really quit aweful. First the ...
# --9e1ONYQuAa-CB_Rrw7Tw  The food was decent, but the service was defin...
# --9e1ONYQuAa-CB_Rrw7Tw  If you're looking for craptastic service and m...
#
#                           type  useful                 user_id
# business_id
# --9e1ONYQuAa-CB_Rrw7Tw  review       0  0XVzm4kVIAaH4eQAxWbhvw
# --9e1ONYQuAa-CB_Rrw7Tw  review       0  2aeNFntqY2QDZLADNo8iQQ
# --9e1ONYQuAa-CB_Rrw7Tw  review       0  WFhv5pMJRDPWSyLnKiWFXA
# --9e1ONYQuAa-CB_Rrw7Tw  review       0  2S6gWE-K3DHNcKYYSgN7xA
# --9e1ONYQuAa-CB_Rrw7Tw  review       1  rCTVWx_Tws2jWi-K89iEyw

# %% [markdown]
# ## Save your preprocessed dataset to csv file
#
# * Respect your laptop's hard work! You don't want to make it run everything again.

# %%
df_reviews_merge = pd.merge(df_reviews_text, df_review_num, how = 'inner', left_index = True, right_index = True)
df_reviews_merge.head()
# Out:
#                                         name  \
# business_id
# --9e1ONYQuAa-CB_Rrw7Tw  Delmonico Steakhouse
# --9e1ONYQuAa-CB_Rrw7Tw  Delmonico Steakhouse
# --9e1ONYQuAa-CB_Rrw7Tw  Delmonico Steakhouse
# --9e1ONYQuAa-CB_Rrw7Tw  Delmonico Steakhouse
# --9e1ONYQuAa-CB_Rrw7Tw  Delmonico Steakhouse
#
#                                                       categories  avg_stars  \
# business_id
# --9e1ONYQuAa-CB_Rrw7Tw  [Steakhouses, Restaurants, Cajun/Creole]        4.0
# --9e1ONYQuAa-CB_Rrw7Tw  [Steakhouses, Restaurants, Cajun/Creole]        4.0
# --9e1ONYQuAa-CB_Rrw7Tw  [Steakhouses, Restaurants, Cajun/Creole]        4.0
# --9e1ONYQuAa-CB_Rrw7Tw  [Steakhouses, Restaurants, Cajun/Creole]        4.0
# --9e1ONYQuAa-CB_Rrw7Tw  [Steakhouses, Restaurants, Cajun/Creole]        4.0
#
#                         cool       date  funny               review_id  stars  \
# business_id
# --9e1ONYQuAa-CB_Rrw7Tw     0 2015-06-26      0  nCqdz-NW64KazpxqnDr0sQ      1
# --9e1ONYQuAa-CB_Rrw7Tw     0 2015-06-29      0  iwx6s6yQxc7yjS7NFANZig      4
# --9e1ONYQuAa-CB_Rrw7Tw     0 2015-04-05      0  2HrBENXZTiitcCJfzkELgA      2
# --9e1ONYQuAa-CB_Rrw7Tw     0 2016-02-16      0  6YNPXoq41qTMZ2TEi0BYUA      2
# --9e1ONYQuAa-CB_Rrw7Tw     0 2016-02-08      1  4bQrVUiRZ642odcKCS0OhQ      2
#
#                                                                      text  \
# business_id
# --9e1ONYQuAa-CB_Rrw7Tw  I mainly went for the ceasar salad prepared ta...
# --9e1ONYQuAa-CB_Rrw7Tw  Nice atmosphere and wonderful service. I had t...
# --9e1ONYQuAa-CB_Rrw7Tw  To be honest it really quit aweful. First the ...
# --9e1ONYQuAa-CB_Rrw7Tw  The food was decent, but the service was defin...
# --9e1ONYQuAa-CB_Rrw7Tw  If you're looking for craptastic service and m...
#
#                           type  useful                 user_id  count
# business_id
# --9e1ONYQuAa-CB_Rrw7Tw  review       0  0XVzm4kVIAaH4eQAxWbhvw    318
# --9e1ONYQuAa-CB_Rrw7Tw  review       0  2aeNFntqY2QDZLADNo8iQQ    318
# --9e1ONYQuAa-CB_Rrw7Tw  review       0  WFhv5pMJRDPWSyLnKiWFXA    318
# --9e1ONYQuAa-CB_Rrw7Tw  review       0  2S6gWE-K3DHNcKYYSgN7xA    318
# --9e1ONYQuAa-CB_Rrw7Tw  review       1  rCTVWx_Tws2jWi-K89iEyw    318

# %%
# Save to ./data/last_2_years_restaurant_reviews.csv for your next task
df_reviews_merge.to_csv('./data/last_2_years_restaurant_reviews.csv', encoding = 'utf-8', index = True)

# %%
df_read_reviews = pd.read_csv('./data/last_2_years_restaurant_reviews.csv')
df_read_reviews.head()
# Out:
#               business_id                  name  \
# 0  --9e1ONYQuAa-CB_Rrw7Tw  Delmonico Steakhouse
# 1  --9e1ONYQuAa-CB_Rrw7Tw  Delmonico Steakhouse
# 2  --9e1ONYQuAa-CB_Rrw7Tw  Delmonico Steakhouse
# 3  --9e1ONYQuAa-CB_Rrw7Tw  Delmonico Steakhouse
# 4  --9e1ONYQuAa-CB_Rrw7Tw  Delmonico Steakhouse
#
#                                  categories  avg_stars  cool        date  \
# 0  [Steakhouses, Restaurants, Cajun/Creole]        4.0     0  2015-06-26
# 1  [Steakhouses, Restaurants, Cajun/Creole]        4.0     0  2015-06-29
# 2  [Steakhouses, Restaurants, Cajun/Creole]        4.0     0  2015-04-05
# 3  [Steakhouses, Restaurants, Cajun/Creole]        4.0     0  2016-02-16
# 4  [Steakhouses, Restaurants, Cajun/Creole]        4.0     0  2016-02-08
#
#    funny               review_id  stars  \
# 0      0  nCqdz-NW64KazpxqnDr0sQ      1
# 1      0  iwx6s6yQxc7yjS7NFANZig      4
# 2      0  2HrBENXZTiitcCJfzkELgA      2
# 3      0  6YNPXoq41qTMZ2TEi0BYUA      2
# 4      1  4bQrVUiRZ642odcKCS0OhQ      2
#
#                                                 text    type  useful  \
# 0  I mainly went for the ceasar salad prepared ta...  review       0
# 1  Nice atmosphere and wonderful service. I had t...  review       0
# 2  To be honest it really quit aweful. First the ...  review       0
# 3  The food was decent, but the service was defin...  review       0
# 4  If you're looking for craptastic service and m...  review       1
#
#                   user_id  count
# 0  0XVzm4kVIAaH4eQAxWbhvw    318
# 1  2aeNFntqY2QDZLADNo8iQQ    318
# 2  WFhv5pMJRDPWSyLnKiWFXA    318
# 3  2S6gWE-K3DHNcKYYSgN7xA    318
# 4  rCTVWx_Tws2jWi-K89iEyw    318

# %%
df_read_reviews.shape
# Out:
# (348016, 14)
